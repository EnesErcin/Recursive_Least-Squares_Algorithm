# %%
import numpy as np
import matplotlib.pylab as plt
import pandas as pa

# %%
dim_x = 2
dim_y = 6

A    = np.random.normal(0,5,(dim_y,dim_x))
C   = np.random.normal(0,5,(dim_y,dim_x))
AT   = np.transpose(A) 
B    = np.random.normal(0,10,(dim_y,1))
A_in = np.linalg.inv(np.matmul(AT,A))

plt.title("A Points observations")
plt.scatter(A[:,0],A[:,1])

# %%
x = np.dot(np.matmul(A_in,AT),B)
p = np.matmul(A,x)

# %%
#Regularized ...

# %%
plt.title("Bestfit line for A_Points observations")
plt.scatter(A[:,0],A[:,1])

starigth_x = np.linspace(-20,20, num=5)
best_fit = x[0] + x[1]*starigth_x 
plt.plot(starigth_x , best_fit, linestyle='--')
